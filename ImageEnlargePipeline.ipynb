# %%
# %pylab inline
rcParams['figure.figsize'] = (10, 4) #wide graphs by default
from __future__ import print_function
from __future__ import division
from scipy.signal import correlate2d
from scipy.ndimage.filters import maximum_filter
from scipy.ndimage.filters import minimum_filter
import PIL
from PIL import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s2= imread('/Users/alexisstorycrawshaw/JP_splotch2.jpg')
imshow(s2)

# %%
s2 = sum(s2[:,:,:-1], axis=2)/3.0
imshow(s2, cmap=cm.gray)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x107eb23b0>

# %%
s2= s2[:,:]/255.0;
s2_black = where(s2 < 0.20, 0, 1)
imshow(s2_black, cmap='gray')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1088a1ab8>

# %%
s2_new=[]

x_start = arange(0,17,1)
y_start = arange(0,15,1)

for x in range(0,17):
    for y in range(0,15):
        double=s2_black[x,y]
        s2_new.append(double)
        s2_new.append(double)
                      
imshow(s2_new, cmap='gray')
