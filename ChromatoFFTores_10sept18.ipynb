# %%
# %pylab inline
from __future__ import print_function
from __future__ import division
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img= imread('/Users/alexisstorycrawshaw/Sepia-officinalis-skin_Roger-Hanlon.jpg')

# %%
imshow(img)

# %%
subplot(131)
imshow(img[:,400:600,0], cmap=cm.gray)
colorbar()
subplot(132)
imshow(img[:,:500,0], cmap=cm.gray)
colorbar()
subplot(133)
imshow(img[:,:-110,0], cmap=cm.gray)
colorbar()

gcf().set_figwidth(14)

# %%
sigLine= img[1,:, 0]
plot(sigLine)

# %%
SigOut = array(((img[:,995,0].astype(int16)-127.5)*100).flat)
plot(SigOut)

# %%
SigOut = array(((((img[:512,:512,0].astype(int16)/3)+(img[:512,:512,1].astype(int16)/3)+(img[:512,:512,2].astype(int16)/3))-127.5)*300).flat)
#SigOut = array(((img[:512,:512,0].astype(int16)-127.5)*200).flat)
plot(SigOut)

# %%
len(SigOut)
# Out:
# 262144

# %%
#win_start = arange(0, 796800, 996)
#win_len = 996
win_start = arange(0, (512*512), 512)
win_len = 512

mag_spectrum = []

for start in win_start:
    win = SigOut[start: start + win_len]
    X = fft.rfft(win)
    mag_spectrum.append(abs(X)/float(win_len/2))

imshow(mag_spectrum, aspect='auto')

# %%
#N = (796800)
N=(512*512)
plot(abs(fft.rfft(SigOut))/ (N/2))

# %%
#win_start = arange(0, 796800, 996)
#win_len = 996
win_start = arange(0, (512*512), 512)
win_len = 512

mag_spectrum = []
real_spectrum= []
imag_spectrum= []
dft = []

for start in win_start:
    win = SigOut[start: start + win_len]
    X = fft.rfft(win)
    
    bin_phs = win
    fft_bin = complex(sum(x*cos(win)),
                     -sum(x*sin(win)))
    dft.append(win)

subplot(121)
plot(real(dft))
title('Real part')

subplot(122)
plot(imag(dft))
title('Imaginary part')

gcf().set_figwidth(10)
    
    
    
    
    mag_spectrum.append(abs(X)/float(win_len/2))
    
    real_spectrum.append(real(X)/float(win_len/2))
    imag_spectrum.append(imag(X)/float(win_len/2))

# %%
subplot(131)
imshow(mag_spectrum, aspect='auto')
colorbar()
subplot(132)
imshow(real_spectrum, aspect='auto')
colorbar()
subplot(133)
imshow(imag_spectrum, aspect='auto')
colorbar()

gcf().set_figwidth(16)

# %%
plot(real_spectrum);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-30f5d11c2fc4> in <module>()
# ----> 1 plot(real_spectrum);
#
# NameError: name 'plot' is not defined

# %%
plot(imag_spectrum)
# Out:
# [<matplotlib.lines.Line2D at 0x109406b10>,
#  <matplotlib.lines.Line2D at 0x109433c10>,
#  <matplotlib.lines.Line2D at 0x109433d90>,
#  <matplotlib.lines.Line2D at 0x109433f10>,
#  <matplotlib.lines.Line2D at 0x1092ca0d0>,
#  <matplotlib.lines.Line2D at 0x1092ca250>,
#  <matplotlib.lines.Line2D at 0x1092ca3d0>,
#  <matplotlib.lines.Line2D at 0x1092db6d0>,
#  <matplotlib.lines.Line2D at 0x1092ca6d0>,
#  <matplotlib.lines.Line2D at 0x1092ca850>,
#  <matplotlib.lines.Line2D at 0x1092ca9d0>,
#  <matplotlib.lines.Line2D at 0x1092cab50>,
#  <matplotlib.lines.Line2D at 0x1092cacd0>,
#  <matplotlib.lines.Line2D at 0x1092cae50>,
#  <matplotlib.lines.Line2D at 0x1092ca550>,
#  <matplotlib.lines.Line2D at 0x1092d5190>,
#  <matplotlib.lines.Line2D at 0x1092d5310>,
#  <matplotlib.lines.Line2D at 0x1092d5490>,
#  <matplotlib.lines.Line2D at 0x1092d5610>,
#  <matplotlib.lines.Line2D at 0x1092d5790>,
#  <matplotlib.lines.Line2D at 0x1092d5910>,
#  <matplotlib.lines.Line2D at 0x1092cafd0>,
#  <matplotlib.lines.Line2D at 0x1092d5c10>,
#  <matplotlib.lines.Line2D at 0x1092d5d90>,
#  <matplotlib.lines.Line2D at 0x1092d5f10>,
#  <matplotlib.lines.Line2D at 0x1092e00d0>,
#  <matplotlib.lines.Line2D at 0x1092e0250>,
#  <matplotlib.lines.Line2D at 0x1092e03d0>,
#  <matplotlib.lines.Line2D at 0x1092d5a90>,
#  <matplotlib.lines.Line2D at 0x1092e06d0>,
#  <matplotlib.lines.Line2D at 0x1092e0850>,
#  <matplotlib.lines.Line2D at 0x1092e09d0>,
#  <matplotlib.lines.Line2D at 0x1092e0b50>,
#  <matplotlib.lines.Line2D at 0x1092e0cd0>,
#  <matplotlib.lines.Line2D at 0x1092e0e50>,
#  <matplotlib.lines.Line2D at 0x1092e0550>,
#  <matplotlib.lines.Line2D at 0x1092ec190>,
#  <matplotlib.lines.Line2D at 0x1092ec310>,
#  <matplotlib.lines.Line2D at 0x1092ec490>,
#  <matplotlib.lines.Line2D at 0x1092ec610>,
#  <matplotlib.lines.Line2D at 0x1092ec790>,
#  <matplotlib.lines.Line2D at 0x1092ec950>,
#  <matplotlib.lines.Line2D at 0x1092e0fd0>,
#  <matplotlib.lines.Line2D at 0x1092eccd0>,
#  <matplotlib.lines.Line2D at 0x1092ece90>,
#  <matplotlib.lines.Line2D at 0x1092f6090>,
#  <matplotlib.lines.Line2D at 0x1092f6250>,
#  <matplotlib.lines.Line2D at 0x1092f6410>,
#  <matplotlib.lines.Line2D at 0x1092f65d0>,
#  <matplotlib.lines.Line2D at 0x1092ecb10>,
#  <matplotlib.lines.Line2D at 0x1092f6950>,
#  <matplotlib.lines.Line2D at 0x1092f6b10>,
#  <matplotlib.lines.Line2D at 0x1092f6cd0>,
#  <matplotlib.lines.Line2D at 0x1092f6e90>,
#  <matplotlib.lines.Line2D at 0x109442090>,
#  <matplotlib.lines.Line2D at 0x109442250>,
#  <matplotlib.lines.Line2D at 0x1092f6790>,
#  <matplotlib.lines.Line2D at 0x1094425d0>,
#  <matplotlib.lines.Line2D at 0x109442790>,
#  <matplotlib.lines.Line2D at 0x109442950>,
#  <matplotlib.lines.Line2D at 0x109442b10>,
#  <matplotlib.lines.Line2D at 0x109442cd0>,
#  <matplotlib.lines.Line2D at 0x109442e90>,
#  <matplotlib.lines.Line2D at 0x109442410>,
#  <matplotlib.lines.Line2D at 0x10944b250>,
#  <matplotlib.lines.Line2D at 0x10944b410>,
#  <matplotlib.lines.Line2D at 0x10944b5d0>,
#  <matplotlib.lines.Line2D at 0x10944b790>,
#  <matplotlib.lines.Line2D at 0x10944b950>,
#  <matplotlib.lines.Line2D at 0x10944bb10>,
#  <matplotlib.lines.Line2D at 0x10944b090>,
#  <matplotlib.lines.Line2D at 0x10944be90>,
#  <matplotlib.lines.Line2D at 0x109452090>,
#  <matplotlib.lines.Line2D at 0x109452250>,
#  <matplotlib.lines.Line2D at 0x109452410>,
#  <matplotlib.lines.Line2D at 0x1094525d0>,
#  <matplotlib.lines.Line2D at 0x109452790>,
#  <matplotlib.lines.Line2D at 0x10944bcd0>,
#  <matplotlib.lines.Line2D at 0x109452b10>,
#  <matplotlib.lines.Line2D at 0x109452cd0>,
#  <matplotlib.lines.Line2D at 0x109452e90>,
#  <matplotlib.lines.Line2D at 0x10945c090>,
#  <matplotlib.lines.Line2D at 0x10945c250>,
#  <matplotlib.lines.Line2D at 0x10945c410>,
#  <matplotlib.lines.Line2D at 0x109452950>,
#  <matplotlib.lines.Line2D at 0x10945c790>,
#  <matplotlib.lines.Line2D at 0x10945c950>,
#  <matplotlib.lines.Line2D at 0x10945cb10>,
#  <matplotlib.lines.Line2D at 0x10945ccd0>,
#  <matplotlib.lines.Line2D at 0x10945ce90>,
#  <matplotlib.lines.Line2D at 0x109466090>,
#  <matplotlib.lines.Line2D at 0x10945c5d0>,
#  <matplotlib.lines.Line2D at 0x109466410>,
#  <matplotlib.lines.Line2D at 0x1094665d0>,
#  <matplotlib.lines.Line2D at 0x109466790>,
#  <matplotlib.lines.Line2D at 0x109466950>,
#  <matplotlib.lines.Line2D at 0x109466b10>,
#  <matplotlib.lines.Line2D at 0x109466cd0>,
#  <matplotlib.lines.Line2D at 0x109466250>,
#  <matplotlib.lines.Line2D at 0x10946e090>,
#  <matplotlib.lines.Line2D at 0x10946e250>,
#  <matplotlib.lines.Line2D at 0x10946e410>,
#  <matplotlib.lines.Line2D at 0x10946e5d0>,
#  <matplotlib.lines.Line2D at 0x10946e790>,
#  <matplotlib.lines.Line2D at 0x10946e950>,
#  <matplotlib.lines.Line2D at 0x109466e90>,
#  <matplotlib.lines.Line2D at 0x10946ecd0>,
#  <matplotlib.lines.Line2D at 0x10946ee90>,
#  <matplotlib.lines.Line2D at 0x109477090>,
#  <matplotlib.lines.Line2D at 0x109477250>,
#  <matplotlib.lines.Line2D at 0x109477410>,
#  <matplotlib.lines.Line2D at 0x1094775d0>,
#  <matplotlib.lines.Line2D at 0x10946eb10>,
#  <matplotlib.lines.Line2D at 0x109477950>,
#  <matplotlib.lines.Line2D at 0x109477b10>,
#  <matplotlib.lines.Line2D at 0x109477cd0>,
#  <matplotlib.lines.Line2D at 0x109477e90>,
#  <matplotlib.lines.Line2D at 0x109480090>,
#  <matplotlib.lines.Line2D at 0x109480250>,
#  <matplotlib.lines.Line2D at 0x109477790>,
#  <matplotlib.lines.Line2D at 0x1094805d0>,
#  <matplotlib.lines.Line2D at 0x109480790>,
#  <matplotlib.lines.Line2D at 0x109480950>,
#  <matplotlib.lines.Line2D at 0x109480b10>,
#  <matplotlib.lines.Line2D at 0x109480cd0>,
#  <matplotlib.lines.Line2D at 0x109480e90>,
#  <matplotlib.lines.Line2D at 0x109480410>,
#  <matplotlib.lines.Line2D at 0x10948a250>,
#  <matplotlib.lines.Line2D at 0x10948a410>,
#  <matplotlib.lines.Line2D at 0x10948a5d0>,
#  <matplotlib.lines.Line2D at 0x10948a790>,
#  <matplotlib.lines.Line2D at 0x10948a950>,
#  <matplotlib.lines.Line2D at 0x10948ab10>,
#  <matplotlib.lines.Line2D at 0x10948a090>,
#  <matplotlib.lines.Line2D at 0x10948ae90>,
#  <matplotlib.lines.Line2D at 0x109492090>,
#  <matplotlib.lines.Line2D at 0x109492250>,
#  <matplotlib.lines.Line2D at 0x109492410>,
#  <matplotlib.lines.Line2D at 0x1094925d0>,
#  <matplotlib.lines.Line2D at 0x109492790>,
#  <matplotlib.lines.Line2D at 0x10948acd0>,
#  <matplotlib.lines.Line2D at 0x109492b10>,
#  <matplotlib.lines.Line2D at 0x109492cd0>,
#  <matplotlib.lines.Line2D at 0x109492e90>,
#  <matplotlib.lines.Line2D at 0x10949c090>,
#  <matplotlib.lines.Line2D at 0x10949c250>,
#  <matplotlib.lines.Line2D at 0x10949c410>,
#  <matplotlib.lines.Line2D at 0x109492950>,
#  <matplotlib.lines.Line2D at 0x10949c790>,
#  <matplotlib.lines.Line2D at 0x10949c950>,
#  <matplotlib.lines.Line2D at 0x10949cb10>,
#  <matplotlib.lines.Line2D at 0x10949ccd0>,
#  <matplotlib.lines.Line2D at 0x10949ce90>,
#  <matplotlib.lines.Line2D at 0x1094a4090>,
#  <matplotlib.lines.Line2D at 0x10949c5d0>,
#  <matplotlib.lines.Line2D at 0x1094a4410>,
#  <matplotlib.lines.Line2D at 0x1094a45d0>,
#  <matplotlib.lines.Line2D at 0x1094a4790>,
#  <matplotlib.lines.Line2D at 0x1094a4950>,
#  <matplotlib.lines.Line2D at 0x1094a4b10>,
#  <matplotlib.lines.Line2D at 0x1094a4cd0>,
#  <matplotlib.lines.Line2D at 0x1094a4250>,
#  <matplotlib.lines.Line2D at 0x1094ad090>,
#  <matplotlib.lines.Line2D at 0x1094ad250>,
#  <matplotlib.lines.Line2D at 0x1094ad410>,
#  <matplotlib.lines.Line2D at 0x1094ad5d0>,
#  <matplotlib.lines.Line2D at 0x1094ad790>,
#  <matplotlib.lines.Line2D at 0x1094ad950>,
#  <matplotlib.lines.Line2D at 0x1094a4e90>,
#  <matplotlib.lines.Line2D at 0x1094adcd0>,
#  <matplotlib.lines.Line2D at 0x1094ade90>,
#  <matplotlib.lines.Line2D at 0x1094b6090>,
#  <matplotlib.lines.Line2D at 0x1094b6250>,
#  <matplotlib.lines.Line2D at 0x1094b6410>,
#  <matplotlib.lines.Line2D at 0x1094b65d0>,
#  <matplotlib.lines.Line2D at 0x1094adb10>,
#  <matplotlib.lines.Line2D at 0x1094b6950>,
#  <matplotlib.lines.Line2D at 0x1094b6b10>,
#  <matplotlib.lines.Line2D at 0x1094b6cd0>,
#  <matplotlib.lines.Line2D at 0x1094b6e90>,
#  <matplotlib.lines.Line2D at 0x1094c0090>,
#  <matplotlib.lines.Line2D at 0x1094c0250>,
#  <matplotlib.lines.Line2D at 0x1094b6790>,
#  <matplotlib.lines.Line2D at 0x1094c05d0>,
#  <matplotlib.lines.Line2D at 0x1094c0790>,
#  <matplotlib.lines.Line2D at 0x1094c0950>,
#  <matplotlib.lines.Line2D at 0x1094c0b10>,
#  <matplotlib.lines.Line2D at 0x1094c0cd0>,
#  <matplotlib.lines.Line2D at 0x1094c0e90>,
#  <matplotlib.lines.Line2D at 0x1094c0410>,
#  <matplotlib.lines.Line2D at 0x1094c8250>,
#  <matplotlib.lines.Line2D at 0x1094c8410>,
#  <matplotlib.lines.Line2D at 0x1094c85d0>,
#  <matplotlib.lines.Line2D at 0x1094c8790>,
#  <matplotlib.lines.Line2D at 0x1094c8950>,
#  <matplotlib.lines.Line2D at 0x1094c8b10>,
#  <matplotlib.lines.Line2D at 0x1094c8090>,
#  <matplotlib.lines.Line2D at 0x1094c8e90>,
#  <matplotlib.lines.Line2D at 0x1094d2090>,
#  <matplotlib.lines.Line2D at 0x1094d2250>,
#  <matplotlib.lines.Line2D at 0x1094d2410>,
#  <matplotlib.lines.Line2D at 0x1094d25d0>,
#  <matplotlib.lines.Line2D at 0x1094d2790>,
#  <matplotlib.lines.Line2D at 0x1094c8cd0>,
#  <matplotlib.lines.Line2D at 0x1094d2b10>,
#  <matplotlib.lines.Line2D at 0x1094d2cd0>,
#  <matplotlib.lines.Line2D at 0x1094d2e90>,
#  <matplotlib.lines.Line2D at 0x1094da090>,
#  <matplotlib.lines.Line2D at 0x1094da250>,
#  <matplotlib.lines.Line2D at 0x1094da410>,
#  <matplotlib.lines.Line2D at 0x1094d2950>,
#  <matplotlib.lines.Line2D at 0x1094da790>,
#  <matplotlib.lines.Line2D at 0x1094da950>,
#  <matplotlib.lines.Line2D at 0x1094dab10>,
#  <matplotlib.lines.Line2D at 0x1094dacd0>,
#  <matplotlib.lines.Line2D at 0x1094dae90>,
#  <matplotlib.lines.Line2D at 0x1094e3090>,
#  <matplotlib.lines.Line2D at 0x1094da5d0>,
#  <matplotlib.lines.Line2D at 0x1094e3410>,
#  <matplotlib.lines.Line2D at 0x1094e35d0>,
#  <matplotlib.lines.Line2D at 0x1094e3790>,
#  <matplotlib.lines.Line2D at 0x1094e3950>,
#  <matplotlib.lines.Line2D at 0x1094e3b10>,
#  <matplotlib.lines.Line2D at 0x1094e3cd0>,
#  <matplotlib.lines.Line2D at 0x1094e3250>,
#  <matplotlib.lines.Line2D at 0x1094ee090>,
#  <matplotlib.lines.Line2D at 0x1094ee250>,
#  <matplotlib.lines.Line2D at 0x1094ee410>,
#  <matplotlib.lines.Line2D at 0x1092e9c10>,
#  <matplotlib.lines.Line2D at 0x1092e9110>,
#  <matplotlib.lines.Line2D at 0x1092dbad0>,
#  <matplotlib.lines.Line2D at 0x1094e3e90>,
#  <matplotlib.lines.Line2D at 0x1092cbb90>,
#  <matplotlib.lines.Line2D at 0x1092bd0d0>,
#  <matplotlib.lines.Line2D at 0x1092bd050>,
#  <matplotlib.lines.Line2D at 0x1092adf90>,
#  <matplotlib.lines.Line2D at 0x1094ee550>,
#  <matplotlib.lines.Line2D at 0x1094ee6d0>,
#  <matplotlib.lines.Line2D at 0x1092db550>,
#  <matplotlib.lines.Line2D at 0x1094ee9d0>,
#  <matplotlib.lines.Line2D at 0x1094eeb50>,
#  <matplotlib.lines.Line2D at 0x1094eecd0>,
#  <matplotlib.lines.Line2D at 0x1094eee50>,
#  <matplotlib.lines.Line2D at 0x1094eefd0>,
#  <matplotlib.lines.Line2D at 0x1094f4190>,
#  <matplotlib.lines.Line2D at 0x1094ee850>,
#  <matplotlib.lines.Line2D at 0x1094f4490>,
#  <matplotlib.lines.Line2D at 0x1094f4610>,
#  <matplotlib.lines.Line2D at 0x1094f4790>,
#  <matplotlib.lines.Line2D at 0x1094f4950>,
#  <matplotlib.lines.Line2D at 0x1094f4b10>,
#  <matplotlib.lines.Line2D at 0x1094f4cd0>,
#  <matplotlib.lines.Line2D at 0x1094f4310>,
#  <matplotlib.lines.Line2D at 0x1094fd090>,
#  <matplotlib.lines.Line2D at 0x1094fd250>,
#  <matplotlib.lines.Line2D at 0x1094fd410>,
#  <matplotlib.lines.Line2D at 0x1094fd5d0>]

# %%
plot(fft.irfft(mag_spectrum))
# Out:
# [<matplotlib.lines.Line2D at 0x1158aa210>,
#  <matplotlib.lines.Line2D at 0x1158aa510>,
#  <matplotlib.lines.Line2D at 0x1158aa810>,
#  <matplotlib.lines.Line2D at 0x1158aab10>,
#  <matplotlib.lines.Line2D at 0x1158aae10>,
#  <matplotlib.lines.Line2D at 0x1155327d0>,
#  <matplotlib.lines.Line2D at 0x115532ad0>,
#  <matplotlib.lines.Line2D at 0x115835610>,
#  <matplotlib.lines.Line2D at 0x1156a2690>,
#  <matplotlib.lines.Line2D at 0x1156c0f50>,
#  <matplotlib.lines.Line2D at 0x1156c0950>,
#  <matplotlib.lines.Line2D at 0x1158ba050>,
#  <matplotlib.lines.Line2D at 0x1158ba350>,
#  <matplotlib.lines.Line2D at 0x1158ba650>,
#  <matplotlib.lines.Line2D at 0x109414310>,
#  <matplotlib.lines.Line2D at 0x1158bac50>,
#  <matplotlib.lines.Line2D at 0x1156c8250>,
#  <matplotlib.lines.Line2D at 0x1156c81d0>,
#  <matplotlib.lines.Line2D at 0x1158c82d0>,
#  <matplotlib.lines.Line2D at 0x1158c8bd0>,
#  <matplotlib.lines.Line2D at 0x1158c8d50>,
#  <matplotlib.lines.Line2D at 0x1158ba950>,
#  <matplotlib.lines.Line2D at 0x1158ac090>,
#  <matplotlib.lines.Line2D at 0x1158ac210>,
#  <matplotlib.lines.Line2D at 0x1158ac390>,
#  <matplotlib.lines.Line2D at 0x1158ac510>,
#  <matplotlib.lines.Line2D at 0x1158ac690>,
#  <matplotlib.lines.Line2D at 0x1158ac810>,
#  <matplotlib.lines.Line2D at 0x1158c8ed0>,
#  <matplotlib.lines.Line2D at 0x1158acb10>,
#  <matplotlib.lines.Line2D at 0x1158acc90>,
#  <matplotlib.lines.Line2D at 0x1158ace10>,
#  <matplotlib.lines.Line2D at 0x1158acf90>,
#  <matplotlib.lines.Line2D at 0x1158b9150>,
#  <matplotlib.lines.Line2D at 0x1158b92d0>,
#  <matplotlib.lines.Line2D at 0x1158ac990>,
#  <matplotlib.lines.Line2D at 0x1158b95d0>,
#  <matplotlib.lines.Line2D at 0x1158b9750>,
#  <matplotlib.lines.Line2D at 0x1158b98d0>,
#  <matplotlib.lines.Line2D at 0x1158b9a50>,
#  <matplotlib.lines.Line2D at 0x1158b9bd0>,
#  <matplotlib.lines.Line2D at 0x1158b9d50>,
#  <matplotlib.lines.Line2D at 0x1158b9450>,
#  <matplotlib.lines.Line2D at 0x115849090>,
#  <matplotlib.lines.Line2D at 0x115849210>,
#  <matplotlib.lines.Line2D at 0x115849390>,
#  <matplotlib.lines.Line2D at 0x115849510>,
#  <matplotlib.lines.Line2D at 0x115849690>,
#  <matplotlib.lines.Line2D at 0x115849810>,
#  <matplotlib.lines.Line2D at 0x1158b9ed0>,
#  <matplotlib.lines.Line2D at 0x115849b10>,
#  <matplotlib.lines.Line2D at 0x115849c90>,
#  <matplotlib.lines.Line2D at 0x115849e10>,
#  <matplotlib.lines.Line2D at 0x115849f90>,
#  <matplotlib.lines.Line2D at 0x115854150>,
#  <matplotlib.lines.Line2D at 0x1158542d0>,
#  <matplotlib.lines.Line2D at 0x115849990>,
#  <matplotlib.lines.Line2D at 0x1158545d0>,
#  <matplotlib.lines.Line2D at 0x115854750>,
#  <matplotlib.lines.Line2D at 0x1158548d0>,
#  <matplotlib.lines.Line2D at 0x115854a50>,
#  <matplotlib.lines.Line2D at 0x115854bd0>,
#  <matplotlib.lines.Line2D at 0x115854d50>,
#  <matplotlib.lines.Line2D at 0x115854450>,
#  <matplotlib.lines.Line2D at 0x11585e090>,
#  <matplotlib.lines.Line2D at 0x11585e210>,
#  <matplotlib.lines.Line2D at 0x11585e390>,
#  <matplotlib.lines.Line2D at 0x11585e510>,
#  <matplotlib.lines.Line2D at 0x11585e690>,
#  <matplotlib.lines.Line2D at 0x11585e810>,
#  <matplotlib.lines.Line2D at 0x115854ed0>,
#  <matplotlib.lines.Line2D at 0x11585eb10>,
#  <matplotlib.lines.Line2D at 0x11585ec90>,
#  <matplotlib.lines.Line2D at 0x11585ee10>,
#  <matplotlib.lines.Line2D at 0x11585ef90>,
#  <matplotlib.lines.Line2D at 0x115869150>,
#  <matplotlib.lines.Line2D at 0x1158692d0>,
#  <matplotlib.lines.Line2D at 0x11585e990>,
#  <matplotlib.lines.Line2D at 0x1158695d0>,
#  <matplotlib.lines.Line2D at 0x115869750>,
#  <matplotlib.lines.Line2D at 0x1158698d0>,
#  <matplotlib.lines.Line2D at 0x115869a50>,
#  <matplotlib.lines.Line2D at 0x115869bd0>,
#  <matplotlib.lines.Line2D at 0x115869d50>,
#  <matplotlib.lines.Line2D at 0x115869450>,
#  <matplotlib.lines.Line2D at 0x115876090>,
#  <matplotlib.lines.Line2D at 0x115876210>,
#  <matplotlib.lines.Line2D at 0x115876390>,
#  <matplotlib.lines.Line2D at 0x115876510>,
#  <matplotlib.lines.Line2D at 0x115876690>,
#  <matplotlib.lines.Line2D at 0x115876810>,
#  <matplotlib.lines.Line2D at 0x115869ed0>,
#  <matplotlib.lines.Line2D at 0x115876b10>,
#  <matplotlib.lines.Line2D at 0x115876c90>,
#  <matplotlib.lines.Line2D at 0x115876e10>,
#  <matplotlib.lines.Line2D at 0x115876f90>,
#  <matplotlib.lines.Line2D at 0x11587e150>,
#  <matplotlib.lines.Line2D at 0x11587e2d0>,
#  <matplotlib.lines.Line2D at 0x115876990>,
#  <matplotlib.lines.Line2D at 0x11587e5d0>,
#  <matplotlib.lines.Line2D at 0x11587e750>,
#  <matplotlib.lines.Line2D at 0x11587e8d0>,
#  <matplotlib.lines.Line2D at 0x11587ea50>,
#  <matplotlib.lines.Line2D at 0x11587ebd0>,
#  <matplotlib.lines.Line2D at 0x11587ed50>,
#  <matplotlib.lines.Line2D at 0x11587e450>,
#  <matplotlib.lines.Line2D at 0x11580c090>,
#  <matplotlib.lines.Line2D at 0x11580c210>,
#  <matplotlib.lines.Line2D at 0x11580c390>,
#  <matplotlib.lines.Line2D at 0x11580c510>,
#  <matplotlib.lines.Line2D at 0x11580c690>,
#  <matplotlib.lines.Line2D at 0x11580c810>,
#  <matplotlib.lines.Line2D at 0x11587eed0>,
#  <matplotlib.lines.Line2D at 0x11580cb10>,
#  <matplotlib.lines.Line2D at 0x11580cc90>,
#  <matplotlib.lines.Line2D at 0x11580ce10>,
#  <matplotlib.lines.Line2D at 0x11580cf90>,
#  <matplotlib.lines.Line2D at 0x115815150>,
#  <matplotlib.lines.Line2D at 0x1158152d0>,
#  <matplotlib.lines.Line2D at 0x11580c990>,
#  <matplotlib.lines.Line2D at 0x1158155d0>,
#  <matplotlib.lines.Line2D at 0x115815750>,
#  <matplotlib.lines.Line2D at 0x1158158d0>,
#  <matplotlib.lines.Line2D at 0x115815a50>,
#  <matplotlib.lines.Line2D at 0x115815bd0>,
#  <matplotlib.lines.Line2D at 0x115815d50>,
#  <matplotlib.lines.Line2D at 0x115815450>,
#  <matplotlib.lines.Line2D at 0x115822090>,
#  <matplotlib.lines.Line2D at 0x115822210>,
#  <matplotlib.lines.Line2D at 0x115822390>,
#  <matplotlib.lines.Line2D at 0x115822510>,
#  <matplotlib.lines.Line2D at 0x115822690>,
#  <matplotlib.lines.Line2D at 0x115822810>,
#  <matplotlib.lines.Line2D at 0x115815ed0>,
#  <matplotlib.lines.Line2D at 0x115822b10>,
#  <matplotlib.lines.Line2D at 0x115822c90>,
#  <matplotlib.lines.Line2D at 0x115822e10>,
#  <matplotlib.lines.Line2D at 0x115822f90>,
#  <matplotlib.lines.Line2D at 0x11582c150>,
#  <matplotlib.lines.Line2D at 0x11582c2d0>,
#  <matplotlib.lines.Line2D at 0x115822990>,
#  <matplotlib.lines.Line2D at 0x11582c5d0>,
#  <matplotlib.lines.Line2D at 0x11582c750>,
#  <matplotlib.lines.Line2D at 0x11582c8d0>,
#  <matplotlib.lines.Line2D at 0x11582ca50>,
#  <matplotlib.lines.Line2D at 0x11582cbd0>,
#  <matplotlib.lines.Line2D at 0x11582cd50>,
#  <matplotlib.lines.Line2D at 0x11582c450>,
#  <matplotlib.lines.Line2D at 0x115837090>,
#  <matplotlib.lines.Line2D at 0x115837210>,
#  <matplotlib.lines.Line2D at 0x115837390>,
#  <matplotlib.lines.Line2D at 0x115837510>,
#  <matplotlib.lines.Line2D at 0x115837690>,
#  <matplotlib.lines.Line2D at 0x115837810>,
#  <matplotlib.lines.Line2D at 0x11582ced0>,
#  <matplotlib.lines.Line2D at 0x115837b10>,
#  <matplotlib.lines.Line2D at 0x115837c90>,
#  <matplotlib.lines.Line2D at 0x115837e10>,
#  <matplotlib.lines.Line2D at 0x115837f90>,
#  <matplotlib.lines.Line2D at 0x115901150>,
#  <matplotlib.lines.Line2D at 0x1159012d0>,
#  <matplotlib.lines.Line2D at 0x115837990>,
#  <matplotlib.lines.Line2D at 0x1159015d0>,
#  <matplotlib.lines.Line2D at 0x115901750>,
#  <matplotlib.lines.Line2D at 0x1159018d0>,
#  <matplotlib.lines.Line2D at 0x115901a50>,
#  <matplotlib.lines.Line2D at 0x115901bd0>,
#  <matplotlib.lines.Line2D at 0x115901d50>,
#  <matplotlib.lines.Line2D at 0x115901450>,
#  <matplotlib.lines.Line2D at 0x11590d090>,
#  <matplotlib.lines.Line2D at 0x11590d210>,
#  <matplotlib.lines.Line2D at 0x11590d390>,
#  <matplotlib.lines.Line2D at 0x11590d510>,
#  <matplotlib.lines.Line2D at 0x11590d690>,
#  <matplotlib.lines.Line2D at 0x11590d810>,
#  <matplotlib.lines.Line2D at 0x115901ed0>,
#  <matplotlib.lines.Line2D at 0x11590db10>,
#  <matplotlib.lines.Line2D at 0x11590dc90>,
#  <matplotlib.lines.Line2D at 0x11590de10>,
#  <matplotlib.lines.Line2D at 0x11590df90>,
#  <matplotlib.lines.Line2D at 0x115917150>,
#  <matplotlib.lines.Line2D at 0x1159172d0>,
#  <matplotlib.lines.Line2D at 0x11590d990>,
#  <matplotlib.lines.Line2D at 0x1159175d0>,
#  <matplotlib.lines.Line2D at 0x115917750>,
#  <matplotlib.lines.Line2D at 0x1159178d0>,
#  <matplotlib.lines.Line2D at 0x115917a50>,
#  <matplotlib.lines.Line2D at 0x115917bd0>,
#  <matplotlib.lines.Line2D at 0x115917d50>,
#  <matplotlib.lines.Line2D at 0x115917450>,
#  <matplotlib.lines.Line2D at 0x115921090>,
#  <matplotlib.lines.Line2D at 0x115921210>,
#  <matplotlib.lines.Line2D at 0x115921390>,
#  <matplotlib.lines.Line2D at 0x115921510>,
#  <matplotlib.lines.Line2D at 0x115921690>,
#  <matplotlib.lines.Line2D at 0x115921810>,
#  <matplotlib.lines.Line2D at 0x115917ed0>,
#  <matplotlib.lines.Line2D at 0x115921b10>,
#  <matplotlib.lines.Line2D at 0x115921c90>,
#  <matplotlib.lines.Line2D at 0x115921e10>,
#  <matplotlib.lines.Line2D at 0x115921f90>,
#  <matplotlib.lines.Line2D at 0x11592b150>,
#  <matplotlib.lines.Line2D at 0x11592b2d0>,
#  <matplotlib.lines.Line2D at 0x115921990>,
#  <matplotlib.lines.Line2D at 0x11592b5d0>,
#  <matplotlib.lines.Line2D at 0x11592b750>,
#  <matplotlib.lines.Line2D at 0x11592b8d0>,
#  <matplotlib.lines.Line2D at 0x11592ba50>,
#  <matplotlib.lines.Line2D at 0x11592bbd0>,
#  <matplotlib.lines.Line2D at 0x11592bd50>,
#  <matplotlib.lines.Line2D at 0x11592b450>,
#  <matplotlib.lines.Line2D at 0x115936090>,
#  <matplotlib.lines.Line2D at 0x115936210>,
#  <matplotlib.lines.Line2D at 0x115936390>,
#  <matplotlib.lines.Line2D at 0x115936510>,
#  <matplotlib.lines.Line2D at 0x115936690>,
#  <matplotlib.lines.Line2D at 0x115936810>,
#  <matplotlib.lines.Line2D at 0x11592bed0>,
#  <matplotlib.lines.Line2D at 0x115936b10>,
#  <matplotlib.lines.Line2D at 0x115936c90>,
#  <matplotlib.lines.Line2D at 0x115936e10>,
#  <matplotlib.lines.Line2D at 0x115936f90>,
#  <matplotlib.lines.Line2D at 0x10dac2150>,
#  <matplotlib.lines.Line2D at 0x10dac22d0>,
#  <matplotlib.lines.Line2D at 0x115936990>,
#  <matplotlib.lines.Line2D at 0x10dac25d0>,
#  <matplotlib.lines.Line2D at 0x10dac2750>,
#  <matplotlib.lines.Line2D at 0x10dac28d0>,
#  <matplotlib.lines.Line2D at 0x10dac2a50>,
#  <matplotlib.lines.Line2D at 0x10dac2bd0>,
#  <matplotlib.lines.Line2D at 0x10dac2d50>,
#  <matplotlib.lines.Line2D at 0x10dac2450>,
#  <matplotlib.lines.Line2D at 0x10dacc090>,
#  <matplotlib.lines.Line2D at 0x10dacc210>,
#  <matplotlib.lines.Line2D at 0x10dacc390>,
#  <matplotlib.lines.Line2D at 0x10dacc510>,
#  <matplotlib.lines.Line2D at 0x1158439d0>,
#  <matplotlib.lines.Line2D at 0x115843750>,
#  <matplotlib.lines.Line2D at 0x10dac2ed0>,
#  <matplotlib.lines.Line2D at 0x115835210>,
#  <matplotlib.lines.Line2D at 0x115827f50>,
#  <matplotlib.lines.Line2D at 0x115817410>,
#  <matplotlib.lines.Line2D at 0x115817290>,
#  <matplotlib.lines.Line2D at 0x115808fd0>,
#  <matplotlib.lines.Line2D at 0x10dacc650>,
#  <matplotlib.lines.Line2D at 0x115835790>,
#  <matplotlib.lines.Line2D at 0x10dacc950>,
#  <matplotlib.lines.Line2D at 0x10daccad0>,
#  <matplotlib.lines.Line2D at 0x10daccc50>,
#  <matplotlib.lines.Line2D at 0x10daccdd0>,
#  <matplotlib.lines.Line2D at 0x10daccf50>,
#  <matplotlib.lines.Line2D at 0x10dad3110>,
#  <matplotlib.lines.Line2D at 0x10dacc7d0>,
#  <matplotlib.lines.Line2D at 0x10dad3410>,
#  <matplotlib.lines.Line2D at 0x10dad3590>,
#  <matplotlib.lines.Line2D at 0x10dad3710>,
#  <matplotlib.lines.Line2D at 0x10dad3890>,
#  <matplotlib.lines.Line2D at 0x10dad3a10>,
#  <matplotlib.lines.Line2D at 0x10dad3b90>,
#  <matplotlib.lines.Line2D at 0x10dad3290>,
#  <matplotlib.lines.Line2D at 0x10dad3e90>,
#  <matplotlib.lines.Line2D at 0x10dadf050>,
#  <matplotlib.lines.Line2D at 0x10dadf1d0>,
#  <matplotlib.lines.Line2D at 0x10dadf350>,
#  <matplotlib.lines.Line2D at 0x10dadf4d0>,
#  <matplotlib.lines.Line2D at 0x10dadf650>,
#  <matplotlib.lines.Line2D at 0x10dad3d10>,
#  <matplotlib.lines.Line2D at 0x10dadf950>,
#  <matplotlib.lines.Line2D at 0x10dadfad0>,
#  <matplotlib.lines.Line2D at 0x10dadfc50>,
#  <matplotlib.lines.Line2D at 0x10dadfdd0>,
#  <matplotlib.lines.Line2D at 0x10dadff50>,
#  <matplotlib.lines.Line2D at 0x10dae7110>,
#  <matplotlib.lines.Line2D at 0x10dadf7d0>,
#  <matplotlib.lines.Line2D at 0x10dae7410>,
#  <matplotlib.lines.Line2D at 0x10dae7590>,
#  <matplotlib.lines.Line2D at 0x10dae7710>,
#  <matplotlib.lines.Line2D at 0x10dae7890>,
#  <matplotlib.lines.Line2D at 0x10dae7a10>,
#  <matplotlib.lines.Line2D at 0x10dae7b90>,
#  <matplotlib.lines.Line2D at 0x10dae7290>,
#  <matplotlib.lines.Line2D at 0x10dae7e90>,
#  <matplotlib.lines.Line2D at 0x10daf3050>,
#  <matplotlib.lines.Line2D at 0x10daf31d0>,
#  <matplotlib.lines.Line2D at 0x10daf3350>,
#  <matplotlib.lines.Line2D at 0x10daf34d0>,
#  <matplotlib.lines.Line2D at 0x10daf3650>,
#  <matplotlib.lines.Line2D at 0x10dae7d10>,
#  <matplotlib.lines.Line2D at 0x10daf3990>,
#  <matplotlib.lines.Line2D at 0x10daf3b50>,
#  <matplotlib.lines.Line2D at 0x10daf3d10>,
#  <matplotlib.lines.Line2D at 0x10daf3ed0>,
#  <matplotlib.lines.Line2D at 0x10dafd0d0>,
#  <matplotlib.lines.Line2D at 0x10dafd290>,
#  <matplotlib.lines.Line2D at 0x10daf37d0>,
#  <matplotlib.lines.Line2D at 0x10dafd610>,
#  <matplotlib.lines.Line2D at 0x10dafd7d0>,
#  <matplotlib.lines.Line2D at 0x10dafd990>,
#  <matplotlib.lines.Line2D at 0x10dafdb50>,
#  <matplotlib.lines.Line2D at 0x10dafdd10>,
#  <matplotlib.lines.Line2D at 0x10dafded0>,
#  <matplotlib.lines.Line2D at 0x10dafd450>,
#  <matplotlib.lines.Line2D at 0x10db07290>,
#  <matplotlib.lines.Line2D at 0x10db07450>,
#  <matplotlib.lines.Line2D at 0x10db07610>,
#  <matplotlib.lines.Line2D at 0x10db077d0>,
#  <matplotlib.lines.Line2D at 0x10db07990>,
#  <matplotlib.lines.Line2D at 0x10db07b50>,
#  <matplotlib.lines.Line2D at 0x10db070d0>,
#  <matplotlib.lines.Line2D at 0x10db07ed0>,
#  <matplotlib.lines.Line2D at 0x10db0f0d0>,
#  <matplotlib.lines.Line2D at 0x10db0f290>,
#  <matplotlib.lines.Line2D at 0x10db0f450>,
#  <matplotlib.lines.Line2D at 0x10db0f610>,
#  <matplotlib.lines.Line2D at 0x10db0f7d0>,
#  <matplotlib.lines.Line2D at 0x10db07d10>,
#  <matplotlib.lines.Line2D at 0x10db0fb50>,
#  <matplotlib.lines.Line2D at 0x10db0fd10>,
#  <matplotlib.lines.Line2D at 0x10db0fed0>,
#  <matplotlib.lines.Line2D at 0x10db160d0>,
#  <matplotlib.lines.Line2D at 0x10db16290>,
#  <matplotlib.lines.Line2D at 0x10db16450>,
#  <matplotlib.lines.Line2D at 0x10db0f990>,
#  <matplotlib.lines.Line2D at 0x10db167d0>,
#  <matplotlib.lines.Line2D at 0x10db16990>,
#  <matplotlib.lines.Line2D at 0x10db16b50>,
#  <matplotlib.lines.Line2D at 0x10db16d10>,
#  <matplotlib.lines.Line2D at 0x10db16ed0>,
#  <matplotlib.lines.Line2D at 0x10db210d0>,
#  <matplotlib.lines.Line2D at 0x10db16610>,
#  <matplotlib.lines.Line2D at 0x10db21450>,
#  <matplotlib.lines.Line2D at 0x10db21610>,
#  <matplotlib.lines.Line2D at 0x10db217d0>,
#  <matplotlib.lines.Line2D at 0x10db21990>,
#  <matplotlib.lines.Line2D at 0x10db21b50>,
#  <matplotlib.lines.Line2D at 0x10db21d10>,
#  <matplotlib.lines.Line2D at 0x10db21290>,
#  <matplotlib.lines.Line2D at 0x10db2a0d0>,
#  <matplotlib.lines.Line2D at 0x10db2a290>,
#  <matplotlib.lines.Line2D at 0x10db2a450>,
#  <matplotlib.lines.Line2D at 0x10db2a610>,
#  <matplotlib.lines.Line2D at 0x10db2a7d0>,
#  <matplotlib.lines.Line2D at 0x10db2a990>,
#  <matplotlib.lines.Line2D at 0x10db21ed0>,
#  <matplotlib.lines.Line2D at 0x10db2ad10>,
#  <matplotlib.lines.Line2D at 0x10db2aed0>,
#  <matplotlib.lines.Line2D at 0x10db330d0>,
#  <matplotlib.lines.Line2D at 0x10db33290>,
#  <matplotlib.lines.Line2D at 0x10db33450>,
#  <matplotlib.lines.Line2D at 0x10db33610>,
#  <matplotlib.lines.Line2D at 0x10db2ab50>,
#  <matplotlib.lines.Line2D at 0x10db33990>,
#  <matplotlib.lines.Line2D at 0x10db33b50>,
#  <matplotlib.lines.Line2D at 0x10db33d10>,
#  <matplotlib.lines.Line2D at 0x10db33ed0>,
#  <matplotlib.lines.Line2D at 0x10db3a0d0>,
#  <matplotlib.lines.Line2D at 0x10db3a290>,
#  <matplotlib.lines.Line2D at 0x10db337d0>,
#  <matplotlib.lines.Line2D at 0x10db3a610>,
#  <matplotlib.lines.Line2D at 0x10db3a7d0>,
#  <matplotlib.lines.Line2D at 0x10db3a990>,
#  <matplotlib.lines.Line2D at 0x10db3ab50>,
#  <matplotlib.lines.Line2D at 0x10db3ad10>,
#  <matplotlib.lines.Line2D at 0x10db3aed0>,
#  <matplotlib.lines.Line2D at 0x10db3a450>,
#  <matplotlib.lines.Line2D at 0x115943290>,
#  <matplotlib.lines.Line2D at 0x115943450>,
#  <matplotlib.lines.Line2D at 0x115943610>,
#  <matplotlib.lines.Line2D at 0x1159437d0>,
#  <matplotlib.lines.Line2D at 0x115943990>,
#  <matplotlib.lines.Line2D at 0x115943b50>,
#  <matplotlib.lines.Line2D at 0x1159430d0>,
#  <matplotlib.lines.Line2D at 0x115943ed0>,
#  <matplotlib.lines.Line2D at 0x11594c0d0>,
#  <matplotlib.lines.Line2D at 0x11594c290>,
#  <matplotlib.lines.Line2D at 0x11594c450>,
#  <matplotlib.lines.Line2D at 0x11594c610>,
#  <matplotlib.lines.Line2D at 0x11594c7d0>,
#  <matplotlib.lines.Line2D at 0x115943d10>,
#  <matplotlib.lines.Line2D at 0x11594cb50>,
#  <matplotlib.lines.Line2D at 0x11594cd10>,
#  <matplotlib.lines.Line2D at 0x11594ced0>,
#  <matplotlib.lines.Line2D at 0x1159540d0>,
#  <matplotlib.lines.Line2D at 0x115954290>,
#  <matplotlib.lines.Line2D at 0x115954450>,
#  <matplotlib.lines.Line2D at 0x11594c990>,
#  <matplotlib.lines.Line2D at 0x1159547d0>,
#  <matplotlib.lines.Line2D at 0x115954990>,
#  <matplotlib.lines.Line2D at 0x115954b50>,
#  <matplotlib.lines.Line2D at 0x115954d10>,
#  <matplotlib.lines.Line2D at 0x115954ed0>,
#  <matplotlib.lines.Line2D at 0x11595e0d0>,
#  <matplotlib.lines.Line2D at 0x115954610>,
#  <matplotlib.lines.Line2D at 0x11595e450>,
#  <matplotlib.lines.Line2D at 0x11595e610>,
#  <matplotlib.lines.Line2D at 0x11595e7d0>,
#  <matplotlib.lines.Line2D at 0x11595e990>,
#  <matplotlib.lines.Line2D at 0x11595eb50>,
#  <matplotlib.lines.Line2D at 0x11595ed10>,
#  <matplotlib.lines.Line2D at 0x11595e290>,
#  <matplotlib.lines.Line2D at 0x1159670d0>,
#  <matplotlib.lines.Line2D at 0x115967290>,
#  <matplotlib.lines.Line2D at 0x115967450>,
#  <matplotlib.lines.Line2D at 0x115967610>,
#  <matplotlib.lines.Line2D at 0x1159677d0>,
#  <matplotlib.lines.Line2D at 0x115967990>,
#  <matplotlib.lines.Line2D at 0x11595eed0>,
#  <matplotlib.lines.Line2D at 0x115967d10>,
#  <matplotlib.lines.Line2D at 0x115967ed0>,
#  <matplotlib.lines.Line2D at 0x11596e0d0>,
#  <matplotlib.lines.Line2D at 0x11596e290>,
#  <matplotlib.lines.Line2D at 0x11596e450>,
#  <matplotlib.lines.Line2D at 0x11596e610>,
#  <matplotlib.lines.Line2D at 0x115967b50>,
#  <matplotlib.lines.Line2D at 0x11596e990>,
#  <matplotlib.lines.Line2D at 0x11596eb50>,
#  <matplotlib.lines.Line2D at 0x11596ed10>,
#  <matplotlib.lines.Line2D at 0x11596eed0>,
#  <matplotlib.lines.Line2D at 0x1159790d0>,
#  <matplotlib.lines.Line2D at 0x115979290>,
#  <matplotlib.lines.Line2D at 0x11596e7d0>,
#  <matplotlib.lines.Line2D at 0x115979610>,
#  <matplotlib.lines.Line2D at 0x1159797d0>,
#  <matplotlib.lines.Line2D at 0x115979990>,
#  <matplotlib.lines.Line2D at 0x115979b50>,
#  <matplotlib.lines.Line2D at 0x115979d10>,
#  <matplotlib.lines.Line2D at 0x115979ed0>,
#  <matplotlib.lines.Line2D at 0x115979450>,
#  <matplotlib.lines.Line2D at 0x10860c290>,
#  <matplotlib.lines.Line2D at 0x10860c450>,
#  <matplotlib.lines.Line2D at 0x10860c610>,
#  <matplotlib.lines.Line2D at 0x10860c7d0>,
#  <matplotlib.lines.Line2D at 0x10860c990>,
#  <matplotlib.lines.Line2D at 0x10860cb50>,
#  <matplotlib.lines.Line2D at 0x10860c0d0>,
#  <matplotlib.lines.Line2D at 0x10860ced0>,
#  <matplotlib.lines.Line2D at 0x1086130d0>,
#  <matplotlib.lines.Line2D at 0x108613290>,
#  <matplotlib.lines.Line2D at 0x108613450>,
#  <matplotlib.lines.Line2D at 0x108613610>,
#  <matplotlib.lines.Line2D at 0x1086137d0>,
#  <matplotlib.lines.Line2D at 0x10860cd10>,
#  <matplotlib.lines.Line2D at 0x108613b50>,
#  <matplotlib.lines.Line2D at 0x108613d10>,
#  <matplotlib.lines.Line2D at 0x108613ed0>,
#  <matplotlib.lines.Line2D at 0x10861d0d0>,
#  <matplotlib.lines.Line2D at 0x10861d290>,
#  <matplotlib.lines.Line2D at 0x10861d450>,
#  <matplotlib.lines.Line2D at 0x108613990>,
#  <matplotlib.lines.Line2D at 0x10861d7d0>,
#  <matplotlib.lines.Line2D at 0x10861d990>,
#  <matplotlib.lines.Line2D at 0x10861db50>,
#  <matplotlib.lines.Line2D at 0x10861dd10>,
#  <matplotlib.lines.Line2D at 0x10861ded0>,
#  <matplotlib.lines.Line2D at 0x1086250d0>,
#  <matplotlib.lines.Line2D at 0x10861d610>,
#  <matplotlib.lines.Line2D at 0x108625450>,
#  <matplotlib.lines.Line2D at 0x108625610>,
#  <matplotlib.lines.Line2D at 0x1086257d0>,
#  <matplotlib.lines.Line2D at 0x108625990>,
#  <matplotlib.lines.Line2D at 0x108625b50>,
#  <matplotlib.lines.Line2D at 0x108625d10>,
#  <matplotlib.lines.Line2D at 0x108625290>,
#  <matplotlib.lines.Line2D at 0x1086300d0>,
#  <matplotlib.lines.Line2D at 0x108630290>,
#  <matplotlib.lines.Line2D at 0x108630450>,
#  <matplotlib.lines.Line2D at 0x108630610>,
#  <matplotlib.lines.Line2D at 0x1086307d0>,
#  <matplotlib.lines.Line2D at 0x108630990>,
#  <matplotlib.lines.Line2D at 0x108625ed0>,
#  <matplotlib.lines.Line2D at 0x108630d10>,
#  <matplotlib.lines.Line2D at 0x108630ed0>,
#  <matplotlib.lines.Line2D at 0x1086390d0>,
#  <matplotlib.lines.Line2D at 0x108639290>,
#  <matplotlib.lines.Line2D at 0x108639450>,
#  <matplotlib.lines.Line2D at 0x108639610>,
#  <matplotlib.lines.Line2D at 0x108630b50>,
#  <matplotlib.lines.Line2D at 0x108639990>,
#  <matplotlib.lines.Line2D at 0x108639b50>,
#  <matplotlib.lines.Line2D at 0x108639d10>,
#  <matplotlib.lines.Line2D at 0x108639ed0>,
#  <matplotlib.lines.Line2D at 0x1086400d0>,
#  <matplotlib.lines.Line2D at 0x108640290>,
#  <matplotlib.lines.Line2D at 0x1086397d0>,
#  <matplotlib.lines.Line2D at 0x108640610>,
#  <matplotlib.lines.Line2D at 0x1086407d0>,
#  <matplotlib.lines.Line2D at 0x108640990>,
#  <matplotlib.lines.Line2D at 0x108640b50>,
#  <matplotlib.lines.Line2D at 0x108640d10>,
#  <matplotlib.lines.Line2D at 0x108640ed0>,
#  <matplotlib.lines.Line2D at 0x108640450>,
#  <matplotlib.lines.Line2D at 0x10864a290>,
#  <matplotlib.lines.Line2D at 0x10864a450>,
#  <matplotlib.lines.Line2D at 0x10864a610>,
#  <matplotlib.lines.Line2D at 0x10864a7d0>,
#  <matplotlib.lines.Line2D at 0x10864a990>,
#  <matplotlib.lines.Line2D at 0x10864ab50>,
#  <matplotlib.lines.Line2D at 0x10864a0d0>,
#  <matplotlib.lines.Line2D at 0x10864aed0>,
#  <matplotlib.lines.Line2D at 0x1086540d0>,
#  <matplotlib.lines.Line2D at 0x108654290>,
#  <matplotlib.lines.Line2D at 0x108654450>,
#  <matplotlib.lines.Line2D at 0x108654610>,
#  <matplotlib.lines.Line2D at 0x1086547d0>,
#  <matplotlib.lines.Line2D at 0x10864ad10>,
#  <matplotlib.lines.Line2D at 0x108654b50>,
#  <matplotlib.lines.Line2D at 0x108654d10>,
#  <matplotlib.lines.Line2D at 0x108654ed0>,
#  <matplotlib.lines.Line2D at 0x10865c0d0>,
#  <matplotlib.lines.Line2D at 0x10865c290>,
#  <matplotlib.lines.Line2D at 0x10865c450>,
#  <matplotlib.lines.Line2D at 0x108654990>]

# %%
from scipy.io import wavfile

newSig=[]

newSig=fft.irfft(mag_spectrum)
wavfile.write('chromatophore_test.wav', 44100, newSig)
